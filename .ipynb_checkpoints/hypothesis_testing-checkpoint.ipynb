# %% [markdown]
# <center><h2> Module 3 Project</h2></center>
# <center><h2> Hypothesis Testing</h2></center>
#
# **Authors:** Ashray Shetty, Fadi Sharaf

# %% [markdown]
# #### Business Problem
#
# Modern music streaming apps have allowed users to listen to music based on their mood and preference withouut being constrained by limitation of space or money. Use of such apps like, spotify has greatly benefited the music industry, by giving users access to songs they would otherwise lack.
#
# Even though the streaming apps allow users to access songs, the mere availability of millions of songs restrict what the users can really discover. Also the use of data from such streaming apps have allowed us to discover patterns and trends in users preference for songs. One such trend is in the seasonaly preference for songs with different energy and acousticness. Certain seasons evoke certain moods which thereby result in users preferring a songs with the right attribute to match the season. We also understand that users prefer streaming different music based on economic performance of the country they reside in.
#
# We therefore wanted to examine if the music industry is uptodate with such trends and do they release songs with certain attributes based on seasons and economy. The attributes we chose to examine is energy, acousticness and danceability. These are attributes of song provided by spotify which is a value between 0 and 1, and they indicate the following:
#
# > 1. **Acousticness**: A confidence measure from 0.0 to 1.0 of whether the track is acoustic. 1.0 represents high confidence the track is acoustic.
# > 2. **Danceability**: Danceability describes how suitable a track is for dancing based on a combination of musical elements including tempo, rhythm stability, beat strength, and overall regularity. A value of 0.0 is least danceable and 1.0 is most danceable.
# > 3. **Energy**: Energy is a measure from 0.0 to 1.0 and represents a perceptual measure of intensity and activity. Typically, energetic tracks feel fast, loud, and noisy. For example, death metal has high energy, while a Bach prelude scores low on the scale. Perceptual features contributing to this attribute include dynamic range, perceived loudness, timbre, onset rate, and general entropy.
#
# The hypothesis which we are planing to investigate and test are as follows:
#
# > **Hypothesis 1: Are there trends in the energy of songs release during economic downturn?**
# >
# > 1. Null: There is no change in the energy of songs when the economy is down
# > 2. Alternative: Songs become more energetic when the economy is down.
#
# > **Hypothesis 2: Are there seasonal trends in the release of high energy songs?**
# >
# > 1. Null: There is no change in energy of songs between differnt seasons.
# > 2. Alternative: Songs have more energy during the summer seasons.
#
# > **Hypothesis 3: Does the acousticness of songs released change depending on seasons?**
# >
# > 1. Null: The Season has no affect on the release of more accoustic songs
# > 2. Alternative: Artist release more accoustic songs during winter.
#
# > **Hypothesis 4: Do the measure of danceability of song change depending on the economy of the country?**
# >
# > 1. Null: Songs are not becoming more danceable
# > 2. Alternative: Songs in 2018 are more danceable than songs in 1999.

# %% [markdown]
# #### Analysis

# %%
import pandas as pd
import data_cleaning as dc
import hypothesis_tests as hypo
import data_cleaning as clean

#dirty_data = pd.read_csv('./data/dirty_data.csv')
#cleaned_data = dc.full_clean(dirty_data)

# %% [markdown]
# # Analysis for hypothesis 2 and 3

# %%
df = pd.read_csv('Song Dataset.csv')

# creating two new column
df['year'] = df['release_date'].map(lambda x: x[:4])
df['month'] = df['release_date'].map(lambda x: x[5:7])
df = df[df.month != ''] # this is because some tracks only have a year mentioned.

# We need to make sure that the new columns are of type int so we can work with them more effectively
df['year'] = df.year.astype(int, inplace=True)
df['month'] = df.month.astype(int, inplace=True)

test_features = ['year', 'month','energy','acousticness']
data = df.loc[:,test_features]
data['seasons'] = data['month'].map(lambda x: clean.seasons(x))

# testing our hypothesis
dftest = data[['seasons','energy','acousticness']]

# testing for all 20 years
features_to_test = ['energy', 'acousticness']
testframe = hypo.seasons_stratifier(dftest)

result = hypo.anova(testframe, 'seasons', features_to_test)
result[['F','PR(>F)', 'eta_sq']]
# Out:
#                                               F    PR(>F)    eta_sq
# ANOVA of Energy against Seasons        1.765784  0.151459  0.001324
# ANOVA of Acousticness against Seasons  4.339256  0.004640  0.003247

# %% [markdown]
# ### Carrying out hypothesis 2 and 3 testing for each year for last 20 years

# %%
dftest2 = data[['year','seasons','energy','acousticness']]
years = [i for i in range (1999, 2019)]

hypo.anova_loop(dftest2, 'seasons', ['energy'], dftest2['year'], years, compact=True)
# Out:
# <style  type="text/css" >
#     #T_e4f3dba0_078f_11ea_b080_acde48001122row0_col0 {
#             background-color:  white;
#             color:  black;
#             border-color:  white;
#         }    #T_e4f3dba0_078f_11ea_b080_acde48001122row0_col1 {
#             background-color:  white;
#             color:  black;
#             border-color:  white;
#         }    #T_e4f3dba0_078f_11ea_b080_acde48001122row0_col2 {
#             background-color:  white;
#             color:  black;
#             border-color:  white;
#         }    #T_e4f3dba0_078f_11ea_b080_acde48001122row1_col0 {
#             background-color:  white;
#             color:  black;
#             border-color:  white;
#         }    #T_e4f3dba0_078f_11ea_b080_acde48001122row1_col1 {
#             background-color:  white;
#             color:  black;
#             border-color:  white;
#         }    #T_e4f3dba0_078f_11ea_b080_acde48001122row1_col2 {
#             background-color:  white;
#             color:  black;
#             border-color:  white;
#         }    #T_e4f3dba0_078f_11ea_b080_acde48001122row2_col0 {
#             background-color:  white;
#             color:  black;
#             border-color:  white;
#         }    #T_e4f3dba0_078f_11ea_b080_acde48001122row2_col1 {
#             background-color:  white;
#             color:  black;
#             border-color:  white;
#         }    #T_e4f3dba0_078f_11ea_b080_acde48001122row2_col2 {
#             background-color:  white;
#             color:  black;
#             border-color:  white;
#         }    #T_e4f3dba0_078f_11ea_b080_acde48001122row3_col0 {
#             background-color:  white;
#             color:  black;
#             border-color:  white;
#         }    #T_e4f3dba0_078f_11ea_b080_acde48001122row3_col1 {
#             background-color:  white;
#             color:  black;
#             border-color:  white;
#         }    #T_e4f3dba0_078f_11ea_b080_acde48001122row3_col2 {
#             background-color:  white;
#             color:  black;
#             border-color:  white;
#         }    #T_e4f3dba0_078f_11ea_b080_acde48001122row4_col0 {
#             background-color:  white;
#             color:  black;
#             border-color:  white;
#         }    #T_e4f3dba0_078f_11ea_b080_acde48001122row4_col1 {
#             background-color:  white;
#             color:  black;
#             border-color:  white;
#         }    #T_e4f3dba0_078f_11ea_b080_acde48001122row4_col2 {
#             background-color:  white;
#             color:  black;
#             border-color:  white;
#         }    #T_e4f3dba0_078f_11ea_b080_acde48001122row5_col0 {
#             background-color:  white;
#             color:  black;
#             border-color:  white;
#         }    #T_e4f3dba0_078f_11ea_b080_acde48001122row5_col1 {
#             background-color:  white;
#             color:  black;
#             border-color:  white;
#         }    #T_e4f3dba0_078f_11ea_b080_acde48001122row5_col2 {
#             background-color:  white;
#             color:  black;
#             border-color:  white;
#         }    #T_e4f3dba0_078f_11ea_b080_acde48001122row6_col0 {
#             background-color:  white;
#             color:  black;
#             border-color:  white;
#         }    #T_e4f3dba0_078f_11ea_b080_acde48001122row6_col1 {
#             background-color:  white;
#             color:  black;
#             border-color:  white;
#         }    #T_e4f3dba0_078f_11ea_b080_acde48001122row6_col2 {
#             background-color:  white;
#             color:  black;
#             border-color:  white;
#         }    #T_e4f3dba0_078f_11ea_b080_acde48001122row7_col0 {
#             background-color:  white;
#             color:  black;
#             border-color:  white;
#         }    #T_e4f3dba0_078f_11ea_b080_acde48001122row7_col1 {
#             background-color:  white;
#             color:  black;
#             border-color:  white;
#         }    #T_e4f3dba0_078f_11ea_b080_acde48001122row7_col2 {
#             background-color:  white;
#             color:  black;
#             border-color:  white;
#         }    #T_e4f3dba0_078f_11ea_b080_acde48001122row8_col0 {
#             background-color:  white;
#             color:  black;
#             border-color:  white;
#         }    #T_e4f3dba0_078f_11ea_b080_acde48001122row8_col1 {
#             background-color:  white;
#             color:  black;
#             border-color:  white;
#         }    #T_e4f3dba0_078f_11ea_b080_acde48001122row8_col2 {
#             background-color:  white;
#             color:  black;
#             border-color:  white;
#         }    #T_e4f3dba0_078f_11ea_b080_acde48001122row9_col0 {
#             background-color:  white;
#             color:  black;
#             border-color:  white;
#         }    #T_e4f3dba0_078f_11ea_b080_acde48001122row9_col1 {
#             background-color:  white;
#             color:  black;
#             border-color:  white;
#         }    #T_e4f3dba0_078f_11ea_b080_acde48001122row9_col2 {
#             background-color:  white;
#             color:  black;
#             border-color:  white;
#         }    #T_e4f3dba0_078f_11ea_b080_acde48001122row10_col0 {
#             background-color:  white;
#             color:  black;
#             border-color:  white;
#         }    #T_e4f3dba0_078f_11ea_b080_acde48001122row10_col1 {
#             background-color:  white;
#             color:  black;
#             border-color:  white;
#         }    #T_e4f3dba0_078f_11ea_b080_acde48001122row10_col2 {
#             background-color:  white;
#             color:  black;
#             border-color:  white;
#         }    #T_e4f3dba0_078f_11ea_b080_acde48001122row11_col0 {
#             background-color:  white;
#             color:  black;
#             border-color:  white;
#         }    #T_e4f3dba0_078f_11ea_b080_acde48001122row11_col1 {
#             background-color:  white;
#             color:  black;
#             border-color:  white;
#         }    #T_e4f3dba0_078f_11ea_b080_acde48001122row11_col2 {
#             background-color:  white;
#             color:  black;
#             border-color:  white;
#         }    #T_e4f3dba0_078f_11ea_b080_acde48001122row12_col0 {
#             background-color:  white;
#             color:  black;
#             border-color:  white;
#         }    #T_e4f3dba0_078f_11ea_b080_acde48001122row12_col1 {
#             background-color:  white;
#             color:  black;
#             border-color:  white;
#         }    #T_e4f3dba0_078f_11ea_b080_acde48001122row12_col2 {
#             background-color:  white;
#             color:  black;
#             border-color:  white;
#         }    #T_e4f3dba0_078f_11ea_b080_acde48001122row13_col0 {
#             background-color:  white;
#             color:  black;
#             border-color:  white;
#         }    #T_e4f3dba0_078f_11ea_b080_acde48001122row13_col1 {
#             background-color:  white;
#             color:  black;
#             border-color:  white;
#         }    #T_e4f3dba0_078f_11ea_b080_acde48001122row13_col2 {
#             background-color:  white;
#             color:  black;
#             border-color:  white;
#         }    #T_e4f3dba0_078f_11ea_b080_acde48001122row14_col0 {
#             background-color:  white;
#             color:  black;
#             border-color:  white;
#         }    #T_e4f3dba0_078f_11ea_b080_acde48001122row14_col1 {
#             background-color:  white;
#             color:  black;
#             border-color:  white;
#         }    #T_e4f3dba0_078f_11ea_b080_acde48001122row14_col2 {
#             background-color:  white;
#             color:  black;
#             border-color:  white;
#         }    #T_e4f3dba0_078f_11ea_b080_acde48001122row15_col0 {
#             background-color:  white;
#             color:  black;
#             border-color:  white;
#         }    #T_e4f3dba0_078f_11ea_b080_acde48001122row15_col1 {
#             background-color:  white;
#             color:  black;
#             border-color:  white;
#         }    #T_e4f3dba0_078f_11ea_b080_acde48001122row15_col2 {
#             background-color:  white;
#             color:  black;
#             border-color:  white;
#         }    #T_e4f3dba0_078f_11ea_b080_acde48001122row16_col0 {
#             background-color:  white;
#             color:  black;

# %%
hypo.anova_loop(dftest2, 'seasons', ['acousticness'], dftest2['year'], years, compact=True)
# Out:
# <style  type="text/css" >
#     #T_e81c058c_078f_11ea_b080_acde48001122row0_col0 {
#             background-color:  white;
#             color:  black;
#             border-color:  white;
#         }    #T_e81c058c_078f_11ea_b080_acde48001122row0_col1 {
#             background-color:  white;
#             color:  black;
#             border-color:  white;
#         }    #T_e81c058c_078f_11ea_b080_acde48001122row0_col2 {
#             background-color:  white;
#             color:  black;
#             border-color:  white;
#         }    #T_e81c058c_078f_11ea_b080_acde48001122row1_col0 {
#             background-color:  white;
#             color:  black;
#             border-color:  white;
#         }    #T_e81c058c_078f_11ea_b080_acde48001122row1_col1 {
#             background-color:  white;
#             color:  black;
#             border-color:  white;
#         }    #T_e81c058c_078f_11ea_b080_acde48001122row1_col2 {
#             background-color:  white;
#             color:  black;
#             border-color:  white;
#         }    #T_e81c058c_078f_11ea_b080_acde48001122row2_col0 {
#             background-color:  white;
#             color:  black;
#             border-color:  white;
#         }    #T_e81c058c_078f_11ea_b080_acde48001122row2_col1 {
#             background-color:  white;
#             color:  black;
#             border-color:  white;
#         }    #T_e81c058c_078f_11ea_b080_acde48001122row2_col2 {
#             background-color:  white;
#             color:  black;
#             border-color:  white;
#         }    #T_e81c058c_078f_11ea_b080_acde48001122row3_col0 {
#             background-color:  white;
#             color:  black;
#             border-color:  white;
#         }    #T_e81c058c_078f_11ea_b080_acde48001122row3_col1 {
#             background-color:  white;
#             color:  black;
#             border-color:  white;
#         }    #T_e81c058c_078f_11ea_b080_acde48001122row3_col2 {
#             background-color:  white;
#             color:  black;
#             border-color:  white;
#         }    #T_e81c058c_078f_11ea_b080_acde48001122row4_col0 {
#             background-color:  white;
#             color:  black;
#             border-color:  white;
#         }    #T_e81c058c_078f_11ea_b080_acde48001122row4_col1 {
#             background-color:  white;
#             color:  black;
#             border-color:  white;
#         }    #T_e81c058c_078f_11ea_b080_acde48001122row4_col2 {
#             background-color:  white;
#             color:  black;
#             border-color:  white;
#         }    #T_e81c058c_078f_11ea_b080_acde48001122row5_col0 {
#             background-color:  white;
#             color:  black;
#             border-color:  white;
#         }    #T_e81c058c_078f_11ea_b080_acde48001122row5_col1 {
#             background-color:  white;
#             color:  black;
#             border-color:  white;
#         }    #T_e81c058c_078f_11ea_b080_acde48001122row5_col2 {
#             background-color:  white;
#             color:  black;
#             border-color:  white;
#         }    #T_e81c058c_078f_11ea_b080_acde48001122row6_col0 {
#             background-color:  white;
#             color:  black;
#             border-color:  white;
#         }    #T_e81c058c_078f_11ea_b080_acde48001122row6_col1 {
#             background-color:  white;
#             color:  black;
#             border-color:  white;
#         }    #T_e81c058c_078f_11ea_b080_acde48001122row6_col2 {
#             background-color:  white;
#             color:  black;
#             border-color:  white;
#         }    #T_e81c058c_078f_11ea_b080_acde48001122row7_col0 {
#             background-color:  white;
#             color:  black;
#             border-color:  white;
#         }    #T_e81c058c_078f_11ea_b080_acde48001122row7_col1 {
#             background-color:  white;
#             color:  black;
#             border-color:  white;
#         }    #T_e81c058c_078f_11ea_b080_acde48001122row7_col2 {
#             background-color:  white;
#             color:  black;
#             border-color:  white;
#         }    #T_e81c058c_078f_11ea_b080_acde48001122row8_col0 {
#             background-color:  white;
#             color:  black;
#             border-color:  white;
#         }    #T_e81c058c_078f_11ea_b080_acde48001122row8_col1 {
#             background-color:  white;
#             color:  black;
#             border-color:  white;
#         }    #T_e81c058c_078f_11ea_b080_acde48001122row8_col2 {
#             background-color:  white;
#             color:  black;
#             border-color:  white;
#         }    #T_e81c058c_078f_11ea_b080_acde48001122row9_col0 {
#             background-color:  white;
#             color:  black;
#             border-color:  white;
#         }    #T_e81c058c_078f_11ea_b080_acde48001122row9_col1 {
#             background-color:  white;
#             color:  black;
#             border-color:  white;
#         }    #T_e81c058c_078f_11ea_b080_acde48001122row9_col2 {
#             background-color:  white;
#             color:  black;
#             border-color:  white;
#         }    #T_e81c058c_078f_11ea_b080_acde48001122row10_col0 {
#             background-color:  white;
#             color:  black;
#             border-color:  white;
#         }    #T_e81c058c_078f_11ea_b080_acde48001122row10_col1 {
#             background-color:  white;
#             color:  black;
#             border-color:  white;
#         }    #T_e81c058c_078f_11ea_b080_acde48001122row10_col2 {
#             background-color:  white;
#             color:  black;
#             border-color:  white;
#         }    #T_e81c058c_078f_11ea_b080_acde48001122row11_col0 {
#             background-color:  white;
#             color:  black;
#             border-color:  white;
#         }    #T_e81c058c_078f_11ea_b080_acde48001122row11_col1 {
#             background-color:  white;
#             color:  black;
#             border-color:  white;
#         }    #T_e81c058c_078f_11ea_b080_acde48001122row11_col2 {
#             background-color:  white;
#             color:  black;
#             border-color:  white;
#         }    #T_e81c058c_078f_11ea_b080_acde48001122row12_col0 {
#             background-color:  white;
#             color:  black;
#             border-color:  white;
#         }    #T_e81c058c_078f_11ea_b080_acde48001122row12_col1 {
#             background-color:  white;
#             color:  black;
#             border-color:  white;
#         }    #T_e81c058c_078f_11ea_b080_acde48001122row12_col2 {
#             background-color:  white;
#             color:  black;
#             border-color:  white;
#         }    #T_e81c058c_078f_11ea_b080_acde48001122row13_col0 {
#             background-color:  white;
#             color:  black;
#             border-color:  white;
#         }    #T_e81c058c_078f_11ea_b080_acde48001122row13_col1 {
#             background-color:  white;
#             color:  black;
#             border-color:  white;
#         }    #T_e81c058c_078f_11ea_b080_acde48001122row13_col2 {
#             background-color:  white;
#             color:  black;
#             border-color:  white;
#         }    #T_e81c058c_078f_11ea_b080_acde48001122row14_col0 {
#             background-color:  white;
#             color:  black;
#             border-color:  white;
#         }    #T_e81c058c_078f_11ea_b080_acde48001122row14_col1 {
#             background-color:  white;
#             color:  black;
#             border-color:  white;
#         }    #T_e81c058c_078f_11ea_b080_acde48001122row14_col2 {
#             background-color:  white;
#             color:  black;
#             border-color:  white;
#         }    #T_e81c058c_078f_11ea_b080_acde48001122row15_col0 {
#             background-color:  white;
#             color:  black;
#             border-color:  white;
#         }    #T_e81c058c_078f_11ea_b080_acde48001122row15_col1 {
#             background-color:  white;
#             color:  black;
#             border-color:  white;
#         }    #T_e81c058c_078f_11ea_b080_acde48001122row15_col2 {
#             background-color:  white;
#             color:  black;
#             border-color:  white;
#         }    #T_e81c058c_078f_11ea_b080_acde48001122row16_col0 {
#             background-color:  white;
#             color:  black;

# %% [markdown]
# #### Findings & Application
#
# We dont find any seasonal trends in the energy and acousticness of songs release through the year. It seems that many in the music indusrty release songs at random regardless of publics general mood during that time of year.
#
# We do however notice that the atrributes of song change during economic downturn. From our statistical testing we had enough evidence to reject the null hypothesis, but we still cannot certainly accept the alternative hypothesis and there could be the existence of factors or variables which we may have missed. Economy is almost always connected with a lot of other industry. Sometimes the connection may be direct, but often there are hidden factors. Our analysis would points us to examine the relationship further.

# %% [markdown]
# #### Limitations
#
# There were a few limitatons which reduce the scope and applicability of our findings in general, most notable among these include:
#
# > 1) **Use of just spotify and billboard 100 data**: These data only provide us with a narrow perspective
# >
# > 2) **Spotify data collected at random irrespective of location**: In order to understand seasonal trends we have to defins seaons accordingly. Since we collected data at random from all over the world, we have no way to defining seasons appropriately for this analysis. This limits the scope of our analysis
# >
# > 3) **Low effect size**: The effect size we observed were very low and indicates that a influence is any could be due to the random variance we observe in our data itself.
# >
# > 4) **High variance of data collected**: We had several data points and they showed a lot of variance, sampling such a data is problmatic.

# %% [markdown]
# #### Next Steps
#
# We could try to identify songs which were popular during the year and see if they should any seasonal trends.
#
# We could also restrict our analysis to a specific location and check for the influence of artist in that location.
#
# We did not subset data based on popular artist, for future work we could subset and check how popular artists are correlated with our work.
